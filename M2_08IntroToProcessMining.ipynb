# %% [markdown]
# <center><font size="+4">Programming & Data Analytics & AI 1 2025/2026</font></center>
# <center><font size="+2">Sant'Anna School of Advanced Studies, Pisa, Italy</font></center>
# <center><img src="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20242025/raw/main/PDAI/jupyter/jupyterNotebooks/images/sssaLEMBEDSdtu.png" width="900" alt="L'EMbeDS"></center>
#
# <center><font size="+2">Course responsible</font></center>
# <center><font size="+2">Andrea Vandin a.vandin@santannapisa.it</font></center>
#
# ---

# %% [markdown]
# <center><font size="+4">Module 2, Part 3, Research-driven topics</font></center>
# <center><font size="+4">Lecture 8: Introduction to</font></center>
# <center><font size="+4">Process-oriented Data Science: Process mining</font></center>
#
# ---

# %% [markdown]
# # Closing
# - __This class concludes the course (PDAI2-ML)__
# - __and its Part 3 on Research-driven/advanced topics__
#
# > __Special thanks to Riccardo Porcedda and Lorenzo Emer!__
#
# <center><img src="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20252026/raw/main/PDAI/jupyter/jupyterNotebooks/images/memeRiccardo.png" width="450" alt="Riccardo"><img src="https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20252026/raw/main/PDAI/jupyter/jupyterNotebooks/images/memeLorenzo.jpeg" width="400" alt="Lorenzo"></center>

# %% [markdown]
# # We need to fix exam dates!
# > __What about Wednesday the 9th of April 2026?__

# %%
googleDoc="https://docs.google.com/document/d/1yy6sZX77aoxbREDq0vIl1Nv0466OEf2qDzOCYzY6-wQ/edit?usp=sharing"
googleDoc
# Out:
# 'https://docs.google.com/document/d/1yy6sZX77aoxbREDq0vIl1Nv0466OEf2qDzOCYzY6-wQ/edit?usp=sharing'

# %%
from IPython.display import IFrame
IFrame(googleDoc, 1300, 700)
# Out:
#         <iframe
#             width="1300"
#             height="700"
#             src="https://docs.google.com/document/d/1yy6sZX77aoxbREDq0vIl1Nv0466OEf2qDzOCYzY6-wQ/edit?usp=sharing"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Overview of Process Mining

# %%
repo='ComputingDataAnalysisModeling20252026'
url_github_repo_basic="https://github.com/EMbeDS-education/"+repo+"/raw/main/"
url_github_repo=url_github_repo_basic+"PDAI/"

from IPython.display import Image, display
img=Image(url_github_repo+'slides/processMining/PM_DS_BPM.png',width=1300)
display(img)

# %% [markdown]
# In this course we will __introduce you to__ the world of __Process Mining__
# - https://en.wikipedia.org/wiki/Process_mining
#
# - Typical data science projects study the data to
#    - Predict properties on future unseen data
#    - Classify the data points in groups
#    - ...
#
# - In this course, instead, we will study the data to
#   - Study the _data generating process_
#     - What is the process that generated the data?
#     - What are its main steps?
#     - Is it correct?
#     - Can it be improved?
# - Processes are everywhere!
#   - When you book an airplane flight several intermediate steps are necessary
#     - Buying a ticket
#       - Identify company
#       - Identify flight
#       - Book flight
#       - Perform payment ...
#       - Payment succeeded
#       - Get ticket
#     - Failing to buy a ticket
#       - Identify company
#       - Identify flight
#       - Book flight
#       - Perform payment ...
#       - Payment failed
#       - Go back to Perform payment ...
#       - Payment succeeded
#       - Get ticket
#   - But, really, processes are everywhere. We will study many examples
#
#
# We hope that after this course it will be clear that
#   - a data scientist can turn data into _greater_ value if considering also processes.
#
#
# This will be an applied course
#   - A lot of examples and analyses
#   - Just a few necessary boring presentations of technical details :D
#   - You will have to produce a process mining project!

# %% [markdown]
# # Further courses
#
# - Very well-done videos for a course by a colleague expert in Process Mining, __Andrea Burattin__, DTU Technical University of Denmark are available here:
#   - https://www.youtube.com/watch?v=YSZmwI1kFg4&list=PL18oAnY_v9R55GM9Moas0Kc-BrEfG3aTx&ab_channel=AndreaBurattin
#
# <br/>
#
# - The 'Process mining course' by the father of Process Mining, __Wil M. P. van der Aalst__, Eindhoven University of Technology, is available for free on Coursera:
#   - Process Mining: Data science in Action
#   - http://coursera.org/learn/process-mining/home/

# %% [markdown]
# ## Can I apply process mining to my own data?
# - __Yes! Event data are everywhere!.__
# - We encourage you to apply the techniques covered in this course to your own data sets, e.g.
#   - data from social networks
#   - data from information systems of enterprises
# - I personally applied it to
#   - Healthcare data
#   - Legal data
#   - 20+ popular public datasets
# - Please, take a look at the notebook on benchmarks and case studies available in this website
#   - https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20242025/wiki/PDAI-Slides,-code-and-other-material

# %%
print('The slides used today')
slides= url_github_repo + "slides/processMining/ProcessMiningTutorial.pdf"
slides
# Out:
# The slides used today
# 'https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20252026/raw/main/PDAI/slides/processMining/ProcessMiningTutorial.pdf'

# %% [markdown]
# # The role of this notebook in this course

# %% [markdown]
# In this notebook, and in the connected slides, we give a _hands on_ introduction to Process Mining
# - What is a process?
# - What is process mining?
# - How can we study processes? Why is it important?
# - What are pm4py and Disco?
#
# We hope you will have fun in this class
# - In case, next year we are going to have a course on this!
# - __PDAI2-PM__

# %%
print('The slides used today')
url_github_repo="https://github.com/EMbeDS-education/"+repo+"/raw/main/PDAI/"
print(url_github_repo+"slides/processMining/ProcessMiningTutorial.pdf")
# Out:
# The slides used today
# https://github.com/EMbeDS-education/ComputingDataAnalysisModeling20252026/raw/main/PDAI/slides/processMining/ProcessMiningTutorial.pdf

# %% [markdown]
# # Understanding processes and process mining

# %% [markdown]
# ## Further material

# %% [markdown]
# Part of the material for this section is from [here](https://pm4py.fit.fraunhofer.de/getting-started-page#understanding)
#
# Further material can be found here
# - [Disco Tour](https://fluxicon.com/disco/files/Disco-Tour.pdf)
# - [Coursera MOOC on Process Mining](https://www.coursera.org/learn/process-mining) (it is for free)
#   - You alaso find a preview (4 chapters) of a fundamental book on which the course is based!

# %% [markdown]
# ## Processes

# %% [markdown]
# Most companies execute several _processes_
# - A process represents a _structured collection of __activities__, resources and personnel_ necessary to reach a __goal__
# - Examples
#   - The process to manufacture a car
#   - The process to cook a pizza
#   - The process to provide a service
#   - __The process to deliver burgers operated by a burger restaurant__
#   - ....

# %% [markdown]
# ## Download files

# %%
url= 'https://raw.githubusercontent.com/EMbeDS-education/'+repo+'/main/PDAI/jupyter/jupyterNotebooks/'

import urllib.request
from pathlib import Path

for csv in ['PurchasingExample.csv','burgers.csv']:
    urllib.request.urlretrieve(url+csv,Path(url+csv).name)

# %% [markdown]
# ## Burger delivery process

# %% [markdown]
# Let us consider the burger example.

# %% [markdown]
# ### Two process instances

# %% [markdown]
# Andrea calls the restaurant McPython's
# - From the __CaPythonE__ chain ;)
#
# __Lucy__ handles the order by performing the following __activities__, in this order, involving also the chef __Luigi__, and the delivery boy __Mike__:
# <ol>
# <li><i><b>Lucy</b> takes your order</i></li>
# <li><i><b>Lucy</b> notes down your address</i></li>
# <li><i><b>Lucy</b> notes down your preferred payment method</i></li>
# <li><i><b>Luigi</b> prepares your burger</i></li>
# <li><i><b>Lucy</b> grabs your can of soda</i></li>
# <li><i><b>Luigi</b> puts your burger in a box</i></li>
# <li><i><b>Lucy</b> wraps your order</i></li>
# <li><i><b>Mike</b> delivers your order</i></li>
# </ol>
#
# This is an __instance__ of the process, or a __trace__

# %% [markdown]
# A few days afterwards, Daniele calls as well the restaurant.
#
# This time, __Randy__ handles the order with the help of the chef __Luigi__ and of the delivery boy __John__:
# <ol>
#                                     <li><i><b>Randy</b> takes your order</i></li>
#                                     <li><i><b>Randy</b> notes down your preferred payment method</i></li>
#                                     <li><i><b>Randy</b> notes down your address</i></li>
#                                     <li><i><b>Luigi</b> prepares your burger</i></li>
#                                     <li><i><b>Luigi</b> puts your burger in a box</i></li>
#                                     <li><i><b>Randy</b> wraps your order</i></li>
#                                     <li><i><b>John</b> delivers your order</i></li>
#                                 </ol>
#
# This is another instance of the process, a trace, where
# - Daniele did not ask for drinks
# - Randy performed certain activities in a different order
#   - He first noted down the payment method, and then the address

# %% [markdown]
# ### Event logs

# %% [markdown]
# Several of such process instances are typically collected into one __event log__
#
# A CSV file with
# - One row per 'event' (per point 1-8, 1-7 above)
#   - An event corresponds to the execution of an activity
# - More rows/events per case/instance
#
# This is a very simple event log of the burger restaurant for Andrea's and Daniele's order

# %%
import pandas as pd
burgers_log=pd.read_csv("burgers.csv")
burgers_log
# Out:
#     case_id                  activity resource         timestamp
# 0      1337                Take Order     Lucy  01/04/2020 13:37
# 1      1337  Note Address of Customer     Lucy  01/04/2020 13:39
# 2      1337   Register Payment Method     Lucy  01/04/2020 13:40
# 3      1337            Prepare Burger    Luigi  01/04/2020 13:41
# 4      1337                 Grab Soda     Lucy  01/04/2020 13:42
# 5      1337         Put Burger in Box    Luigi  01/04/2020 13:52
# 6      1337                Wrap Order     Lucy  01/04/2020 13:53
# 7      1337             Deliver Order     Mike  01/04/2020 13:55
# 8      1538                Take Order    Randy  08/04/2020 12:37
# 9      1538   Register Payment Method    Randy  08/04/2020 12:39
# 10     1538  Note Address of Customer    Randy  08/04/2020 12:40
# 11     1538            Prepare Burger    Luigi  08/04/2020 12:41
# 12     1538         Put Burger in Box    Luigi  08/04/2020 12:52
# 13     1538                Wrap Order    Randy  08/04/2020 12:53
# 14     1538             Deliver Order     John  08/04/2020 12:55

# %% [markdown]
# Andrea's order

# %%
burgers_log[burgers_log.case_id==1337]
# Out:
#    case_id                  activity resource         timestamp
# 0     1337                Take Order     Lucy  01/04/2020 13:37
# 1     1337  Note Address of Customer     Lucy  01/04/2020 13:39
# 2     1337   Register Payment Method     Lucy  01/04/2020 13:40
# 3     1337            Prepare Burger    Luigi  01/04/2020 13:41
# 4     1337                 Grab Soda     Lucy  01/04/2020 13:42
# 5     1337         Put Burger in Box    Luigi  01/04/2020 13:52
# 6     1337                Wrap Order     Lucy  01/04/2020 13:53
# 7     1337             Deliver Order     Mike  01/04/2020 13:55

# %% [markdown]
# ### Process discovery

# %% [markdown]
# Starting from an event log, we can run __discovery algorithms__ from process mining to
# - synthetize a system description (a process) that matches the observed logs
#
# For the event log above we obtain:

# %%
from IPython.display import Image, display
img=Image(url_github_repo+'slides/processMining/actual_simple_sample_model.png',width=1300)
#savefig(img)
display(img)

# %% [markdown]
# We can see that
# - 2 of events can be executed in parallel
#   - Note address and Register Payment Method
# - Grab soda is optional

# %% [markdown]
# The above process can be generated using a Python library for Process mining
# - [PM4PY](https://processintelligence.solutions/static/api/2.7.11/getting_started.html)
# - However, it is a bit too 'technical' for today's class.
#
# Today we will focus on a graphical easy-to-use industrial tool
# - [Disco](https://fluxicon.com/disco/)
# - It focuses on providing more intuitive process descriptions easily understandable by domain experts
#
# Disco's output for the simple event-log is:

# %%
from IPython.display import Image, display
#img=Image(filename='images/tentativeLecturePlan.png',width=700)

img=Image(url_github_repo+'slides/processMining/burgers.png',width=500)
display(img)

# %% [markdown]
# # Process discovery with pm4py

# %% [markdown]
# > __This example requires you to have [graphviz](https://graphviz.org/download/) installed__
#
# It works on colab

# %% [markdown]
# ## Install/load libraries

# %%
#The first time you need to install pm4py
# %pip install pm4py
# Out:
# Collecting pm4py
#   Downloading pm4py-2.7.19.8-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (from pm4py) (2.4.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (from pm4py) (3.0.1)
# Requirement already satisfied: networkx in ./.venv/lib/python3.13/site-packages (from pm4py) (3.6.1)
# Collecting graphviz (from pm4py)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy in ./.venv/lib/python3.13/site-packages (from pm4py) (1.17.1)
# Collecting lxml (from pm4py)
#   Downloading lxml-6.0.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.13/site-packages (from pm4py) (3.10.8)
# Collecting pytz (from pm4py)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.13/site-packages (from pm4py) (4.67.3)
# Requirement already satisfied: wheel in ./.venv/lib/python3.13/site-packages (from pm4py) (0.46.3)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.13/site-packages (from pm4py) (82.0.0)
# Collecting cvxopt (from pm4py)
#   Downloading cvxopt-1.3.3-cp313-cp313-macosx_15_0_arm64.whl.metadata (43 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.13/site-packages (from matplotlib->pm4py) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.13/site-packages (from matplotlib->pm4py) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.13/site-packages (from matplotlib->pm4py) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib->pm4py) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from matplotlib->pm4py) (26.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.13/site-packages (from matplotlib->pm4py) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.13/site-packages (from matplotlib->pm4py) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.13/site-packages (from matplotlib->pm4py) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->pm4py) (1.17.0)
# Downloading pm4py-2.7.19.8-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 1.2 MB/s  0:00:01 eta 0:00:010m
# Downloading cvxopt-1.3.3-cp313-cp313-macosx_15_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 1.2 MB/s  0:00:03 eta 0:00:01
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading lxml-6.0.2-cp313-cp313-macosx_10_13_universal2.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 1.2 MB/s  0:00:07 eta 0:00:01
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Installing collected packages: pytz, lxml, graphviz, cvxopt, pm4py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [pm4py]32m4/5 [pm4py]]
# Successfully installed cvxopt-1.3.3 graphviz-0.21 lxml-6.0.2 pm4py-2.7.19.8 pytz-2026.1.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
#Now you import pandas and pm4py
import pandas as pd
import pm4py

# %%
from importlib.metadata import version
version('pm4py')
# Out:
# '2.7.19.8'

# %% [markdown]
# ## Load and inspect data

# %%
file_path="burgers.csv"
event_log = pd.read_csv(file_path, sep=',')

#set right type in the timestamp column
event_log['timestamp']=pd.to_datetime(event_log['timestamp'])

event_log.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   case_id    15 non-null     int64
#  1   activity   15 non-null     str
#  2   resource   15 non-null     str
#  3   timestamp  15 non-null     datetime64[us]
# dtypes: datetime64[us](1), int64(1), str(2)
# memory usage: 612.0 bytes

# %%
num_events = event_log.shape[0]
num_cases = len(event_log.case_id.unique())
num_activities = len(event_log.activity.unique())
print("Number of events:    {}\nNumber of cases:      {}\nNumber of activities: {}".format(num_events, num_cases,num_activities))
event_log
# Out:
# Number of events:    15
# Number of cases:      2
# Number of activities: 8
#     case_id                  activity resource           timestamp
# 0      1337                Take Order     Lucy 2020-01-04 13:37:00
# 1      1337  Note Address of Customer     Lucy 2020-01-04 13:39:00
# 2      1337   Register Payment Method     Lucy 2020-01-04 13:40:00
# 3      1337            Prepare Burger    Luigi 2020-01-04 13:41:00
# 4      1337                 Grab Soda     Lucy 2020-01-04 13:42:00
# 5      1337         Put Burger in Box    Luigi 2020-01-04 13:52:00
# 6      1337                Wrap Order     Lucy 2020-01-04 13:53:00
# 7      1337             Deliver Order     Mike 2020-01-04 13:55:00
# 8      1538                Take Order    Randy 2020-08-04 12:37:00
# 9      1538   Register Payment Method    Randy 2020-08-04 12:39:00
# 10     1538  Note Address of Customer    Randy 2020-08-04 12:40:00
# 11     1538            Prepare Burger    Luigi 2020-08-04 12:41:00
# 12     1538         Put Burger in Box    Luigi 2020-08-04 12:52:00
# 13     1538                Wrap Order    Randy 2020-08-04 12:53:00
# 14     1538             Deliver Order     John 2020-08-04 12:55:00

# %%
event_log = pm4py.format_dataframe(event_log, case_id='case_id', activity_key='activity', timestamp_key='timestamp')
start_activities = pm4py.get_start_activities(event_log)
end_activities = pm4py.get_end_activities(event_log)
print("Start activities: {}\nEnd activities: {}".format(start_activities, end_activities))
# Out:
# Start activities: {'Take Order': 2}
# End activities: {'Deliver Order': 2}

# %% [markdown]
# ## Generate and view BPMN

# %%
process_tree = pm4py.discover_process_tree_inductive(event_log)
#print(process_tree)

#from pm4py.visualization.process_tree import visualizer as pt_visualizer
#gviz = pt_visualizer.apply(process_tree, parameters={pt_visualizer.Variants.WO_DECORATION.value.Parameters.FORMAT: "png"})
#pt_visualizer.view(gviz)

bpmn_model = pm4py.convert_to_bpmn(process_tree)
pm4py.view_bpmn(bpmn_model)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/graphviz/backend/execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py:1991, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1990 if err_filename is not None:
# -> 1991     raise child_exception_type(errno_num, err_msg, err_filename)
#    1992 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: PosixPath('dot')
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# Cell In[17], line 9
#       2 #print(process_tree)
#       3
#       4 #from pm4py.visualization.process_tree import visualizer as pt_visualizer
#       5 #gviz = pt_visualizer.apply(process_tree, parameters={pt_visualizer.Variants.WO_DECORATION.value.Parameters.FORMAT: "png"})
#       6 #pt_visualizer.view(gviz)
#       8 bpmn_model = pm4py.convert_to_bpmn(process_tree)
# ----> 9 pm4py.view_bpmn(bpmn_model)
#
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/pm4py/vis.py:562, in view_bpmn(bpmn_graph, format, bgcolor, rankdir, variant_str, graph_title)
#     560 props = _setup_parameters(fmt, bgcolor, rankdir, graph_title)
#     561 gviz = bpmn_visualizer.apply(bpmn_graph, variant=variant, parameters=props)
# --> 562 bpmn_visualizer.view(gviz, variant=variant)
#
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/pm4py/visualization/bpmn/visualizer.py:98, in view(gviz, variant, parameters)
#      89 def view(gviz: graphviz.Digraph, variant=DEFAULT_VARIANT, parameters=None):
#      90     """
#      91     View the diagram
#      92
#    (...)     96         GraphViz diagram
#      97     """
# ---> 98     return exec_utils.get_variant(variant).view(gviz, parameters=parameters)
#
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/pm4py/visualization/bpmn/variants/classic.py:265, in view(gviz, parameters)
#     256 """
#     257 View the diagram
#     258
#    (...)    262     GraphViz diagram
#     263 """
#     264 if constants.DEFAULT_ENABLE_VISUALIZATIONS_VIEW:
# --> 265     return gview.view(gviz, parameters=parameters)
#
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/pm4py/visualization/common/gview.py:50, in view(gviz, parameters)
#      48     html.view(gviz, parameters=parameters)
#      49 elif vis_utils.check_visualization_inside_jupyter():
# ---> 50     vis_utils.view_image_in_jupyter(gviz.render())
#      51 elif format == "gv":
#      52     print(str(gviz))
#
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/graphviz/_tools.py:185, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     177     wanted = ', '.join(f'{name}={value!r}'
#     178                        for name, value in deprecated.items())
#     179     warnings.warn(f'The signature of {func_name} will be reduced'
#     180                   f' to {supported_number} positional arg{s_}{qualification}'
#     181                   f' {list(supported)}: pass {wanted} as keyword arg{s_}',
#     182                   stacklevel=stacklevel,
#     183                   category=category)
# --> 185 return func(*args, **kwargs)
#
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/graphviz/rendering.py:122, in Render.render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     118 filepath = self.save(filename, directory=directory, skip_existing=None)
#     120 args.append(filepath)
# --> 122 rendered = self._render(*args, **kwargs)
#     124 if cleanup:
#     125     log.debug('delete %r', filepath)
#
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/graphviz/_tools.py:185, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     177     wanted = ', '.join(f'{name}={value!r}'
#     178                        for name, value in deprecated.items())
#     179     warnings.warn(f'The signature of {func_name} will be reduced'
#     180                   f' to {supported_number} positional arg{s_}{qualification}'
#     181                   f' {list(supported)}: pass {wanted} as keyword arg{s_}',
#     182                   stacklevel=stacklevel,
#     183                   category=category)
# --> 185 return func(*args, **kwargs)
#
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/graphviz/backend/rendering.py:326, in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     322 cmd += args
#     324 assert filepath is not None, 'work around pytype false alarm'
# --> 326 execute.run_check(cmd,
#     327                   cwd=filepath.parent if filepath.parent.parts else None,
#     328                   quiet=quiet,
#     329                   capture_output=True)
#     331 return os.fspath(outfile)
#
# File ~/Desktop/Programming-Data-Analytics-AI-II-personal/.venv/lib/python3.13/site-packages/graphviz/backend/execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      79 except OSError as e:
#      80     if e.errno == errno.ENOENT:
# ---> 81         raise ExecutableNotFound(cmd) from e
#      82     raise
#      84 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute PosixPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %% [markdown]
# ## Generate and view Process map (aka dependecy graph, Disco-style)

# %%
dfg, start_activities, end_activities = pm4py.discover_dfg(event_log)
pm4py.view_dfg(dfg, start_activities, end_activities)

# %% [markdown]
# ## Further material

# %% [markdown]
# An application of pm4py to the healthcare domain
# - [Part 1](https://medium.com/@c3_62722/process-mining-with-python-tutorial-a-healthcare-application-part-1-ae02027a050)
# - [Part 2](https://medium.com/@c3_62722/process-mining-with-python-tutorial-a-healthcare-application-part-2-4cf57053421f)
# - [Part 3](https://medium.com/@c3_62722/process-mining-with-python-tutorial-a-healthcare-application-part-3-cc9af986c122)
# - [Part 4](https://medium.com/@c3_62722/process-mining-with-python-tutorial-a-healthcare-application-part-4-912286ee51b)

# %% [markdown]
# # Material for tutorial on Fluxicon Disco

# %% [markdown]
# ## Load data

# %%
import pandas as pd

# %%
logs = pd.read_csv("PurchasingExample.csv")
logs["Start Timestamp"]=pd.to_datetime(logs["Start Timestamp"])
logs["Complete Timestamp"]=pd.to_datetime(logs["Complete Timestamp"])
logs.sort_values(by="Start Timestamp",inplace=True)

logs
# Out:
#       Case ID     Start Timestamp  Complete Timestamp  \
# 0           1 2011-01-01 00:00:00 2011-01-01 00:37:00
# 1           2 2011-01-01 00:16:00 2011-01-01 00:29:00
# 2           3 2011-01-01 02:23:00 2011-01-01 03:03:00
# 3           1 2011-01-01 05:37:00 2011-01-01 05:45:00
# 4           1 2011-01-01 06:41:00 2011-01-01 06:55:00
# ...       ...                 ...                 ...
# 9114     1284 2011-10-14 13:53:00 2011-10-14 14:07:00
# 9115     1448 2011-10-14 13:56:00 2011-10-14 14:24:00
# 9116     1941 2011-10-14 14:05:00 2011-10-14 14:18:00
# 9117     1448 2011-10-14 14:24:00 2011-10-14 14:24:00
# 9118     1448 2011-10-14 15:16:00 2011-10-14 15:31:00
#
#                                   Activity             Resource  \
# 0              Create Purchase Requisition            Kim Passa
# 1              Create Purchase Requisition  Immanuel Karagianni
# 2              Create Purchase Requisition            Kim Passa
# 3             Create Request for Quotation            Kim Passa
# 4            Analyze Request for Quotation       Karel de Groot
# ...                                    ...                  ...
# 9114                           Pay Invoice        Pedro Alvares
# 9115          Settle Dispute With Supplier      Karalda Nimwada
# 9116         Analyze Request for Quotation       Karel de Groot
# 9117  Authorize Supplier's Invoice payment      Karalda Nimwada
# 9118                           Pay Invoice      Karalda Nimwada
#
#                    Role
# 0             Requester
# 1             Requester
# 2             Requester
# 3             Requester
# 4      Purchasing Agent
# ...                 ...
# 9114  Financial Manager
# 9115  Financial Manager
# 9116   Purchasing Agent
# 9117  Financial Manager
# 9118  Financial Manager
#
# [9119 rows x 6 columns]

# %%
logs.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9119 entries, 0 to 9118
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Case ID             9119 non-null   int64
#  1   Start Timestamp     9119 non-null   datetime64[us]
#  2   Complete Timestamp  9119 non-null   datetime64[us]
#  3   Activity            9119 non-null   str
#  4   Resource            9119 non-null   str
#  5   Role                9119 non-null   str
# dtypes: datetime64[us](2), int64(1), str(3)
# memory usage: 498.7 KB

# %% [markdown]
# ## Extract the case with ID 1

# %%
logs[logs["Case ID"]==1]
# Out:
#      Case ID     Start Timestamp  Complete Timestamp  \
# 0          1 2011-01-01 00:00:00 2011-01-01 00:37:00
# 3          1 2011-01-01 05:37:00 2011-01-01 05:45:00
# 4          1 2011-01-01 06:41:00 2011-01-01 06:55:00
# 12         1 2011-01-01 11:43:00 2011-01-01 12:09:00
# 13         1 2011-01-01 12:32:00 2011-01-01 16:03:00
# 36         1 2011-01-01 22:44:00 2011-01-01 23:13:00
# 37         1 2011-01-01 23:13:00 2011-01-01 23:13:00
# 42         1 2011-01-02 01:22:00 2011-01-02 09:20:00
# 60         1 2011-01-02 09:58:00 2011-01-02 10:10:00
# 68         1 2011-01-02 14:09:00 2011-01-02 14:43:00
# 97         1 2011-01-02 20:49:00 2011-01-03 03:37:00
# 137        1 2011-01-03 11:20:00 2011-01-03 11:21:00
# 176        1 2011-01-03 19:09:00 2011-01-03 19:10:00
# 221        1 2011-01-04 00:54:00 2011-01-04 00:54:00
# 276        1 2011-01-04 15:08:00 2011-01-04 15:13:00
# 277        1 2011-01-04 15:13:00 2011-01-04 15:13:00
# 278        1 2011-01-04 15:22:00 2011-01-04 15:31:00
#
#                                    Activity             Resource  \
# 0               Create Purchase Requisition            Kim Passa
# 3              Create Request for Quotation            Kim Passa
# 4             Analyze Request for Quotation       Karel de Groot
# 12   Send Request for Quotation to Supplier       Karel de Groot
# 13          Create Quotation comparison Map   Magdalena Predutta
# 36         Analyze Quotation Comparison Map  Immanuel Karagianni
# 37                       Choose best option          Tesca Lobes
# 42          Settle Conditions With Supplier  Francois de Perrier
# 60                    Create Purchase Order       Karel de Groot
# 68                   Confirm Purchase Order          Sean Manney
# 97                   Deliver Goods Services          Sean Manney
# 137                  Release Purchase Order         Elvira Lores
# 176      Approve Purchase Order for payment       Karel de Groot
# 221                            Send Invoice              Kiu Kan
# 276              Release Supplier's Invoice      Karalda Nimwada
# 277    Authorize Supplier's Invoice payment      Karalda Nimwada
# 278                             Pay Invoice        Pedro Alvares
#
#                   Role
# 0            Requester
# 3            Requester
# 4     Purchasing Agent
# 12    Purchasing Agent
# 13    Purchasing Agent
# 36           Requester
# 37           Requester
# 42    Purchasing Agent
# 60    Purchasing Agent
# 68            Supplier
# 97            Supplier
# 137          Requester
# 176   Purchasing Agent
# 221           Supplier
# 276  Financial Manager
# 277  Financial Manager
# 278  Financial Manager

# %% [markdown]
# ## Extract the case with ID 2

# %%
logs[logs["Case ID"]==2]
# Out:
#      Case ID     Start Timestamp  Complete Timestamp  \
# 1          2 2011-01-01 00:16:00 2011-01-01 00:29:00
# 5          2 2011-01-01 08:16:00 2011-01-01 08:26:00
# 7          2 2011-01-01 09:34:00 2011-01-01 09:38:00
# 9          2 2011-01-01 10:16:00 2011-01-01 10:21:00
# 10         2 2011-01-01 11:15:00 2011-01-01 11:48:00
# 14         2 2011-01-01 12:33:00 2011-01-01 12:39:00
# 15         2 2011-01-01 13:28:00 2011-01-01 13:38:00
# 18         2 2011-01-01 15:18:00 2011-01-01 15:40:00
# 19         2 2011-01-01 15:55:00 2011-01-01 16:43:00
# 39         2 2011-01-01 23:33:00 2011-01-01 23:44:00
# 40         2 2011-01-01 23:44:00 2011-01-01 23:44:00
# 47         2 2011-01-02 02:15:00 2011-01-02 15:07:00
# 77         2 2011-01-02 16:21:00 2011-01-02 16:31:00
# 94         2 2011-01-02 20:23:00 2011-01-02 20:29:00
# 123        2 2011-01-03 03:15:00 2011-01-04 14:53:00
# 312        2 2011-01-04 23:01:00 2011-01-04 23:02:00
# 342        2 2011-01-05 09:03:00 2011-01-05 09:04:00
# 367        2 2011-01-05 14:50:00 2011-01-05 14:50:00
# 409        2 2011-01-06 05:04:00 2011-01-06 05:07:00
# 411        2 2011-01-06 05:38:00 2011-01-06 05:58:00
# 413        2 2011-01-06 05:58:00 2011-01-06 05:58:00
# 415        2 2011-01-06 06:21:00 2011-01-06 06:32:00
#
#                                    Activity             Resource  \
# 1               Create Purchase Requisition  Immanuel Karagianni
# 5              Create Request for Quotation       Alberto Duport
# 7             Analyze Request for Quotation       Karel de Groot
# 9               Amend Request for Quotation   Christian Francois
# 10            Analyze Request for Quotation   Magdalena Predutta
# 14              Amend Request for Quotation      Esmana Liubiata
# 15            Analyze Request for Quotation       Karel de Groot
# 18   Send Request for Quotation to Supplier  Francois de Perrier
# 19          Create Quotation comparison Map       Karel de Groot
# 39         Analyze Quotation Comparison Map      Esmana Liubiata
# 40                       Choose best option      Fjodor Kowalski
# 47          Settle Conditions With Supplier   Magdalena Predutta
# 77                    Create Purchase Order   Magdalena Predutta
# 94                   Confirm Purchase Order       Esmeralda Clay
# 123                  Deliver Goods Services       Esmeralda Clay
# 312                  Release Purchase Order         Elvira Lores
# 342      Approve Purchase Order for payment       Karel de Groot
# 367                            Send Invoice       Esmeralda Clay
# 409              Release Supplier's Invoice        Pedro Alvares
# 411            Settle Dispute With Supplier      Karalda Nimwada
# 413    Authorize Supplier's Invoice payment        Pedro Alvares
# 415                             Pay Invoice      Karalda Nimwada
#
#                   Role
# 1            Requester
# 5            Requester
# 7     Purchasing Agent
# 9            Requester
# 10    Purchasing Agent
# 14           Requester
# 15    Purchasing Agent
# 18    Purchasing Agent
# 19    Purchasing Agent
# 39           Requester
# 40           Requester
# 47    Purchasing Agent
# 77    Purchasing Agent
# 94            Supplier
# 123           Supplier
# 312          Requester
# 342   Purchasing Agent
# 367           Supplier
# 409  Financial Manager
# 411  Financial Manager
# 413  Financial Manager
# 415  Financial Manager

# %% [markdown]
# ## How many cases?

# %%
len(logs["Case ID"].unique())
# Out:
# 608
